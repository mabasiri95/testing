# %% [markdown]
# * test 1
# * test 2

# %% [markdown]
# # import library

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # the rest

# %% [markdown]
# ### Hello, this is test

# %%
print("helloo")

# %% [markdown]
# ## the data

# %%
x = [1, 2, 3, 4, 5]
y = [1, 3, 4, 2, 6]
print(x)
# Out:
# [1, 2, 3, 4, 5]

# %%
plt.plot(x, y)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Simple Plot of x vs y")
plt.grid(True)
plt.show()
